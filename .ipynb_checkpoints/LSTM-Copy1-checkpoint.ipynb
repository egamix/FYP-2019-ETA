# %%
from __future__ import print_function

from IPython import display

import math
import matplotlib
import sklearn
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from numpy import radians, cos, sin, arcsin, arccos, sqrt, pi, arctan2, degrees, arctan

from tqdm import tqdm, tqdm_notebook
tqdm.pandas()
tqdm.pandas(tqdm_notebook)

from joblib import dump, load

from natsort import natsorted
from sklearn.model_selection import train_test_split
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV, train_test_split
from sklearn import metrics

pd.options.display.max_rows = 10

# %%
def haversine(lat1, lon1, lat2, lon2):
    #ensure using numpy and not math, or pandas series cannot be passed
    lat1, lon1, lat2, lon2 = map(radians, [lat1, lon1, lat2, lon2])
    dlon = lon2 - lon1
    dlat = lat2 - lat1
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * arcsin(sqrt(a))
    r = 6378.137 ##radius of earth km
    return c * r

def compute_dist(df):
    next_df = df.shift(1)
    dist = haversine(df.iloc[:,0], df.iloc[:,1],
                    next_df.iloc[:,0], next_df.iloc[:,1])
    return dist

def compute_time(df):
    next_df = df.shift(1)
#     df["time"] = pd.to_datetime(df["time_utc"], format="%Y-%m-%d %H:%M:%S.%f", errors='raise')
    timedelt = df["time"] - next_df["time"]
    return timedelt

def compute_speed(df):
    kinematics = df.copy()
    kinematics["distance_travelled"] = compute_dist(kinematics[["latitude", "longitude"]].astype(float)).values
    kinematics["time_elapsed"] = compute_time(kinematics).values
    kinematics["time_elapsed_seconds"] = kinematics["time_elapsed"]/np.timedelta64(1,'s')
    kinematics["speed m/s"] = (kinematics["distance_travelled"]*1000)/kinematics["time_elapsed_seconds"]
    kinematics["speed kmh"] = kinematics["speed m/s"]*3.6
    kinematics["bearing"] = compute_bearing(kinematics[["latitude", "longitude"]].astype(float))
    kinematics['bearing_diff'] = compute_bearing_diff(kinematics)
    kinematics["rate_of_turn"] = kinematics["bearing_diff"]/kinematics["time_elapsed_seconds"]
    kinematics["acceleration"] = (speed_diff(kinematics["speed m/s"])) /kinematics["time_elapsed_seconds"]
    kinematics.drop(columns = ['time_elapsed'], inplace = True)
    kinematics.fillna(0, inplace = True)
#     df["distance_travelled"] = kinematics["distance_travelled"].values
#     df["speed kmh"] = kinematics["speed kmh"].values
    return kinematics

def compute_bearing(df):
    next_df = df.shift(1)
    bear = cal_bearing(df.iloc[:,0], df.iloc[:,1],
                    next_df.iloc[:,0], next_df.iloc[:,1])
    return bear

def bearing_diff(bearing, prev_bearing):
    
    """
    Calculates the absolute difference between two angles
    Parameters
      bearing: bearing in degrees of the first angle
      prev_bearing: bearing in degrees of the second angle
    Returns the difference in degrees as a float
    """

    # if bearing - prev_bearing <=180 then taking the absolute difference is correct
    if bearing - prev_bearing <= 180:
        bearing_diff = abs(bearing - prev_bearing)
    # otherwise if bearing is larger than previous_bearing the total difference is the prev_bearing plus the difference
    # between 360 and the bearing
    elif bearing > prev_bearing:
        bearing_diff = prev_bearing + (360 - bearing)
    # otherwise if prev_bearing is larger than bearing the total difference is the bearing plus the difference 
    # between 360 and the prev_bearing
    elif prev_bearing > bearing:
        bearing_diff = bearing + (360 - prev_bearing)
    # in all other cases take the absolute difference
    else:
        bearing_diff = abs(bearing - prev_bearing)

    return bearing_diff

def cal_bearing(lat1, lon1, lat2, lon2):
    """
    Calculates the bearing between two points using the formula
        θ = atan2(sin(Δlong).cos(lat2),
                  cos(lat1).sin(lat2) − sin(lat1).cos(lat2).cos(Δlong))
    """
    
    lat1, lon1, lat2, lon2 = map(radians, [lat1, lon1, lat2, lon2])

    dlon = lon2 - lon1

    x = sin(dlon) * cos(lat2)
    y1 = cos(lat1) * sin(lat2)
    y2 = sin(lat1) * cos(lat2) * cos(dlon)
    y = y1 - y2

    initial_bearing = arctan2(x, y)

    initial_bearing = degrees(initial_bearing)
    compass_bearing = (initial_bearing + 360) % 360

    return compass_bearing

def compute_bearing_diff(df):
    df1 = df.copy()
    df1["prev_bearing"] = df1["bearing"].shift(1)
    df1["bearing diff"] = df1.apply(lambda row: bearing_diff(row['bearing'],row['prev_bearing']),axis=1)
    return df1["bearing diff"]

def speed_diff(df):
    next_df = df.shift(1)
    diff = df - next_df
    return diff

def compute_speed(df):
    kinematics = df.copy()
    kinematics["distance_travelled"] = compute_dist(kinematics[["latitude", "longitude"]].astype(float)).values
    kinematics["time_elapsed"] = compute_time(kinematics).values
    kinematics["time_elapsed_seconds"] = kinematics["time_elapsed"]/np.timedelta64(1,'s')
    kinematics["speed m/s"] = (kinematics["distance_travelled"]*1000)/kinematics["time_elapsed_seconds"]
    kinematics["speed kmh"] = kinematics["speed m/s"]*3.6
    kinematics["bearing"] = compute_bearing(kinematics[["latitude", "longitude"]].astype(float))
    kinematics['bearing_diff'] = compute_bearing_diff(kinematics)
    kinematics["rate_of_turn"] = kinematics["bearing_diff"]/kinematics["time_elapsed_seconds"]
    kinematics["acceleration"] = (speed_diff(kinematics["speed m/s"])) /kinematics["time_elapsed_seconds"]
    kinematics.drop(columns = ['time_elapsed'], inplace = True)
    kinematics.fillna(0, inplace = True)
#     df["distance_travelled"] = kinematics["distance_travelled"].values
#     df["speed kmh"] = kinematics["speed kmh"].values
    return kinematics

# %%
tt = pd.read_csv('./4798.txt', header  = None, parse_dates = [1])
tt.columns = ['ID', 'time', 'longitude', 'latitude']

# %%
tt = tt[tt['time'] < '2008-2-3' ]
tt = tt[tt['longitude'] > 100]
tt= tt[tt['latitude'] > 35]

# %%
df =  pd.read_csv('/mnt/hgfs/FYP/porto_cleaned_100000.csv', parse_dates = ['time'])

# %%
grouper = df.groupby('ID')

# %%
a = []
b = []
c = []
for name, val in tqdm(grouper):
    idx_grper = val.groupby(val['Unnamed: 0'].diff().ne(1).cumsum())
    for name2, taxi in idx_grper:
        a.append(len(taxi))
        b.append(name)
        c.append(taxi)

# %%
val = df[df['ID'] == 20000496]

# %%
a = []
b = []
idx_grper = val.groupby(val['Unnamed: 0'].diff().ne(1).cumsum())
for name, taxi in idx_grper:
    a.append(taxi)
    b.append(len(taxi))

# %%
tt.plot('longitude', 'latitude', kind = 'scatter', figsize = (16,9))

# %%
df2 = c[4]

# %%
df2
# Out:
#        Unnamed: 0                time  longitude   latitude        ID
# 78690           0 2013-07-01 10:55:57  -8.607096  41.150331  20000001
# 78691           1 2013-07-01 10:56:12  -8.607096  41.150313  20000001
# 78692           2 2013-07-01 10:56:27  -8.607141  41.150241  20000001
# 78693           3 2013-07-01 10:56:42  -8.607150  41.150232  20000001
# 78694           4 2013-07-01 10:56:57  -8.607600  41.149233  20000001
# ...           ...                 ...        ...        ...       ...
# 78732          42 2013-07-01 11:07:42  -8.567118  41.174604  20000001
# 78733          43 2013-07-01 11:07:57  -8.567118  41.174568  20000001
# 78734          44 2013-07-01 11:08:12  -8.566569  41.175000  20000001
# 78735          45 2013-07-01 11:08:27  -8.565768  41.175162  20000001
# 78736          46 2013-07-01 11:08:42  -8.565732  41.174712  20000001
#
# [47 rows x 5 columns]

# %%
df2 = compute_speed(tt)

# %%
df2.plot('time', 'speed kmh')

# %%
def time_to_dest(df):
    end_time = df['time'].iloc[-1]
    df['time_to_dest'] = (end_time - df['time']).dt.total_seconds().astype(int)
def set_dropoff(df):
    df['dropoff_latitude'] = df['latitude'].iloc[-1]
    df['dropoff_longitude'] = df['longitude'].iloc[-1]

# %%
time_to_dest(df2)
set_dropoff(df2)

df2['dist_to_dest'] = haversine(df2['latitude'].values, df2['longitude'].values, df2['dropoff_latitude'].values, df2['dropoff_longitude'].values)

# %%
df2['pickup_weekday'] = df2['time'].dt.weekday
df2['pickup_hour_weekofyear'] = df2['time'].dt.weekofyear
df2['pickup_hour'] = df2['time'].dt.hour
df2['pickup_minute'] = df2['time'].dt.minute
df2['pickup_dt'] = (df2['time'] - df2['time'].min()).dt.total_seconds()
df2['pickup_week_hour'] = df2['pickup_weekday'] * 24 + df2['pickup_hour']

# %%
df2
# Out:
#        Unnamed: 0                time  longitude   latitude        ID  \
# 78690           0 2013-07-01 10:55:57  -8.607096  41.150331  20000001
# 78691           1 2013-07-01 10:56:12  -8.607096  41.150313  20000001
# 78692           2 2013-07-01 10:56:27  -8.607141  41.150241  20000001
# 78693           3 2013-07-01 10:56:42  -8.607150  41.150232  20000001
# 78694           4 2013-07-01 10:56:57  -8.607600  41.149233  20000001
# ...           ...                 ...        ...        ...       ...
# 78732          42 2013-07-01 11:07:42  -8.567118  41.174604  20000001
# 78733          43 2013-07-01 11:07:57  -8.567118  41.174568  20000001
# 78734          44 2013-07-01 11:08:12  -8.566569  41.175000  20000001
# 78735          45 2013-07-01 11:08:27  -8.565768  41.175162  20000001
# 78736          46 2013-07-01 11:08:42  -8.565732  41.174712  20000001
#
#        distance_travelled  time_elapsed_seconds  speed m/s  speed kmh  \
# 78690            0.000000                   0.0   0.000000   0.000000
# 78691            0.002004                  15.0   0.133583   0.480900
# 78692            0.008858                  15.0   0.590549   2.125975
# 78693            0.001254                  15.0   0.083609   0.300994
# 78694            0.117431                  15.0   7.828743  28.183474
# ...                   ...                   ...        ...        ...
# 78732            0.076792                  15.0   5.119464  18.430072
# 78733            0.004008                  15.0   0.267167   0.961800
# 78734            0.066549                  15.0   4.436591  15.971727
# 78735            0.069497                  15.0   4.633108  16.679190
# 78736            0.050185                  15.0   3.345634  12.044282
#
#           bearing  ...  time_to_dest  dropoff_latitude  dropoff_longitude  \
# 78690    0.000000  ...           765         41.174712          -8.565732
# 78691    0.000000  ...           750         41.174712          -8.565732
# 78692   25.202430  ...           735         41.174712          -8.565732
# 78693   36.979259  ...           720         41.174712          -8.565732
# 78694   18.736059  ...           705         41.174712          -8.565732
# ...           ...  ...           ...               ...                ...
# 78732  214.721015  ...            60         41.174712          -8.565732
# 78733    0.000000  ...            45         41.174712          -8.565732
# 78734  223.728363  ...            30         41.174712          -8.565732
# 78735  254.960394  ...            15         41.174712          -8.565732
# 78736  356.554037  ...             0         41.174712          -8.565732
#
#        dist_to_dest  pickup_weekday  pickup_hour_weekofyear  pickup_hour  \
# 78690      4.402649               0                      27           10
# 78691      4.403885               0                      27           10
# 78692      4.411801               0                      27           10
# 78693      4.413013               0                      27           10
# 78694      4.511826               0                      27           10
# ...             ...             ...                     ...          ...
# 78732      0.116755               0                      27           11
# 78733      0.117235               0                      27           11
# 78734      0.077113               0                      27           11
# 78735      0.050185               0                      27           11
# 78736      0.000000               0                      27           11
#
#        pickup_minute  pickup_dt  pickup_week_hour
# 78690             55        0.0                10
# 78691             56       15.0                10
# 78692             56       30.0                10
# 78693             56       45.0                10
# 78694             56       60.0                10
# ...              ...        ...               ...
# 78732              7      705.0                11
# 78733              7      720.0                11
# 78734              8      735.0                11
# 78735              8      750.0                11
# 78736              8      765.0                11
#
# [47 rows x 23 columns]

# %%
train_x = df2.drop(['Unnamed: 0', 'time', 'ID', 'time_elapsed_seconds', 'time_to_dest'] ,axis =1)
train_y = df2[['time_to_dest']]

# %%
x_data = train_x.values
x_data = np.array(x_data)
# x_data = x_data.reshape(19828,5,1)
x_data.shape
# Out:
# (47, 18)

# %%
y_data = train_y.values
y_data.shape
# Out:
# (47, 1)

# %%
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.layers.recurrent import LSTM,RNN
from tensorflow.python.keras.layers.core import Dense, Activation, Dropout

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.2, random_state=42)

# %%
# sc = MinMaxScaler(feature_range=(-1,1))
scy = MinMaxScaler(feature_range=(-1,1))
sc = sklearn.preprocessing.StandardScaler()
# new_df= x_data[].reshape(x_data.shape[0],5)

x_train = sc.fit_transform(x_train)
x_train = x_train.reshape(37,18,1)
x_test = sc.transform(x_test).reshape(10,18,1)


y_train = scy.fit_transform(y_train)
y_test = scy.transform(y_test)

# new_y_data = y_data
# new_y_data = scy.fit_transform(y_)

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (37, 18, 1)
# (37, 1)
# (10, 18, 1)
# (10, 1)

# %%
model = Sequential()

# first layer
model.add(LSTM(units=100, batch_input_shape=(None,18,1),return_sequences=True))
model.add(Dropout(0.2))

# second layer
# model.add(Dense(128, 1))
model.add(LSTM(units=100,return_sequences=True))
model.add(Dropout(0.2))

# third layer
model.add(LSTM(units=50,return_sequences=False))
model.add(Dropout(0.2))

# fourth dense layer
model.add(Dense(units=1))


model.compile(loss='mean_absolute_error',optimizer='adam',metrics=['mae'])
model.summary()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_35 (LSTM)               (None, 18, 100)           40800
# _________________________________________________________________
# dropout_35 (Dropout)         (None, 18, 100)           0
# _________________________________________________________________
# lstm_36 (LSTM)               (None, 18, 100)           80400
# _________________________________________________________________
# dropout_36 (Dropout)         (None, 18, 100)           0
# _________________________________________________________________
# lstm_37 (LSTM)               (None, 50)                30200
# _________________________________________________________________
# dropout_37 (Dropout)         (None, 50)                0
# _________________________________________________________________
# dense_12 (Dense)             (None, 1)                 51
# =================================================================
# Total params: 151,451
# Trainable params: 151,451
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x_train,y_train,epochs=50,validation_data=(x_test,y_test))
# Out:
# Train on 37 samples, validate on 10 samples
# Epoch 1/50
# 37/37 [==============================] - 3s 78ms/sample - loss: 0.5382 - mean_absolute_error: 0.5382 - val_loss: 0.3942 - val_mean_absolute_error: 0.3942
# Epoch 2/50
# 37/37 [==============================] - 0s 4ms/sample - loss: 0.5144 - mean_absolute_error: 0.5144 - val_loss: 0.3538 - val_mean_absolute_error: 0.3538
# Epoch 3/50
# 37/37 [==============================] - 0s 4ms/sample - loss: 0.4905 - mean_absolute_error: 0.4905 - val_loss: 0.3180 - val_mean_absolute_error: 0.3180
# Epoch 4/50
# 37/37 [==============================] - 0s 4ms/sample - loss: 0.4456 - mean_absolute_error: 0.4456 - val_loss: 0.3034 - val_mean_absolute_error: 0.3034
# Epoch 5/50
# 37/37 [==============================] - 0s 4ms/sample - loss: 0.3590 - mean_absolute_error: 0.3590 - val_loss: 0.3192 - val_mean_absolute_error: 0.3192
# Epoch 6/50
# 37/37 [==============================] - 0s 4ms/sample - loss: 0.3898 - mean_absolute_error: 0.3898 - val_loss: 0.3626 - val_mean_absolute_error: 0.3626
# Epoch 7/50
# 37/37 [==============================] - 0s 4ms/sample - loss: 0.4556 - mean_absolute_error: 0.4556 - val_loss: 0.3568 - val_mean_absolute_error: 0.3568
# Epoch 8/50
# 37/37 [==============================] - 0s 6ms/sample - loss: 0.4311 - mean_absolute_error: 0.4311 - val_loss: 0.3346 - val_mean_absolute_error: 0.3346
# Epoch 9/50
# 37/37 [==============================] - 0s 4ms/sample - loss: 0.3506 - mean_absolute_error: 0.3506 - val_loss: 0.3054 - val_mean_absolute_error: 0.3054
# Epoch 10/50
# 37/37 [==============================] - 0s 4ms/sample - loss: 0.3175 - mean_absolute_error: 0.3175 - val_loss: 0.2935 - val_mean_absolute_error: 0.2935
# Epoch 11/50
# 37/37 [==============================] - 0s 4ms/sample - loss: 0.3451 - mean_absolute_error: 0.3451 - val_loss: 0.2659 - val_mean_absolute_error: 0.2659
# Epoch 12/50
# 37/37 [==============================] - 0s 4ms/sample - loss: 0.3542 - mean_absolute_error: 0.3542 - val_loss: 0.2417 - val_mean_absolute_error: 0.2417
# Epoch 13/50
# 37/37 [==============================] - 0s 5ms/sample - loss: 0.3474 - mean_absolute_error: 0.3474 - val_loss: 0.2367 - val_mean_absolute_error: 0.2367
# Epoch 14/50
# 37/37 [==============================] - 0s 4ms/sample - loss: 0.3257 - mean_absolute_error: 0.3257 - val_loss: 0.2466 - val_mean_absolute_error: 0.2466
# Epoch 15/50
# 37/37 [==============================] - 0s 4ms/sample - loss: 0.3153 - mean_absolute_error: 0.3153 - val_loss: 0.2784 - val_mean_absolute_error: 0.2784
# Epoch 16/50
# 37/37 [==============================] - 0s 5ms/sample - loss: 0.3026 - mean_absolute_error: 0.3026 - val_loss: 0.2917 - val_mean_absolute_error: 0.2917
# Epoch 17/50
# 37/37 [==============================] - 0s 5ms/sample - loss: 0.3019 - mean_absolute_error: 0.3019 - val_loss: 0.2944 - val_mean_absolute_error: 0.2944
# Epoch 18/50
# 37/37 [==============================] - 0s 4ms/sample - loss: 0.3187 - mean_absolute_error: 0.3187 - val_loss: 0.2708 - val_mean_absolute_error: 0.2708
# Epoch 19/50
# 37/37 [==============================] - 0s 3ms/sample - loss: 0.2889 - mean_absolute_error: 0.2889 - val_loss: 0.2612 - val_mean_absolute_error: 0.2612
# Epoch 20/50
# 37/37 [==============================] - 0s 4ms/sample - loss: 0.2432 - mean_absolute_error: 0.2432 - val_loss: 0.3058 - val_mean_absolute_error: 0.3058
# Epoch 21/50
# 37/37 [==============================] - 0s 4ms/sample - loss: 0.3171 - mean_absolute_error: 0.3171 - val_loss: 0.3636 - val_mean_absolute_error: 0.3636
# Epoch 22/50
# 37/37 [==============================] - 0s 5ms/sample - loss: 0.3769 - mean_absolute_error: 0.3769 - val_loss: 0.3622 - val_mean_absolute_error: 0.3622
# Epoch 23/50
# 37/37 [==============================] - 0s 4ms/sample - loss: 0.3459 - mean_absolute_error: 0.3459 - val_loss: 0.2980 - val_mean_absolute_error: 0.2980
# Epoch 24/50
# 37/37 [==============================] - 0s 4ms/sample - loss: 0.2892 - mean_absolute_error: 0.2892 - val_loss: 0.2651 - val_mean_absolute_error: 0.2651
# Epoch 25/50
# 37/37 [==============================] - 0s 4ms/sample - loss: 0.2656 - mean_absolute_error: 0.2656 - val_loss: 0.2649 - val_mean_absolute_error: 0.2649
# Epoch 26/50
# 37/37 [==============================] - 0s 3ms/sample - loss: 0.2841 - mean_absolute_error: 0.2841 - val_loss: 0.3004 - val_mean_absolute_error: 0.3004
# Epoch 27/50
# 37/37 [==============================] - 0s 4ms/sample - loss: 0.3173 - mean_absolute_error: 0.3173 - val_loss: 0.3285 - val_mean_absolute_error: 0.3285
# Epoch 28/50
# 37/37 [==============================] - 0s 3ms/sample - loss: 0.3678 - mean_absolute_error: 0.3678 - val_loss: 0.3121 - val_mean_absolute_error: 0.3121
# Epoch 29/50
# 37/37 [==============================] - 0s 4ms/sample - loss: 0.3318 - mean_absolute_error: 0.3318 - val_loss: 0.2714 - val_mean_absolute_error: 0.2714
# Epoch 30/50
# 37/37 [==============================] - 0s 5ms/sample - loss: 0.2714 - mean_absolute_error: 0.2714 - val_loss: 0.2385 - val_mean_absolute_error: 0.2385
# Epoch 31/50
# 37/37 [==============================] - 0s 4ms/sample - loss: 0.2843 - mean_absolute_error: 0.2843 - val_loss: 0.2570 - val_mean_absolute_error: 0.2570
# Epoch 32/50
# 37/37 [==============================] - 0s 4ms/sample - loss: 0.3076 - mean_absolute_error: 0.3076 - val_loss: 0.2625 - val_mean_absolute_error: 0.2625
# Epoch 33/50
# 37/37 [==============================] - 0s 4ms/sample - loss: 0.3737 - mean_absolute_error: 0.3737 - val_loss: 0.2628 - val_mean_absolute_error: 0.2628
# Epoch 34/50
# 37/37 [==============================] - 0s 4ms/sample - loss: 0.3710 - mean_absolute_error: 0.3710 - val_loss: 0.2535 - val_mean_absolute_error: 0.2535
# Epoch 35/50
# 37/37 [==============================] - 0s 4ms/sample - loss: 0.3285 - mean_absolute_error: 0.3285 - val_loss: 0.2410 - val_mean_absolute_error: 0.2410
# Epoch 36/50
# 37/37 [==============================] - 0s 4ms/sample - loss: 0.2875 - mean_absolute_error: 0.2875 - val_loss: 0.2371 - val_mean_absolute_error: 0.2371
# Epoch 37/50
# 37/37 [==============================] - 0s 5ms/sample - loss: 0.2487 - mean_absolute_error: 0.2487 - val_loss: 0.2535 - val_mean_absolute_error: 0.2535
# Epoch 38/50
# 37/37 [==============================] - 0s 4ms/sample - loss: 0.2568 - mean_absolute_error: 0.2568 - val_loss: 0.2604 - val_mean_absolute_error: 0.2604
# Epoch 39/50
# 37/37 [==============================] - 0s 3ms/sample - loss: 0.2764 - mean_absolute_error: 0.2764 - val_loss: 0.2683 - val_mean_absolute_error: 0.2683
# Epoch 40/50
# 37/37 [==============================] - 0s 4ms/sample - loss: 0.2584 - mean_absolute_error: 0.2584 - val_loss: 0.2654 - val_mean_absolute_error: 0.2654
# Epoch 41/50
# 37/37 [==============================] - 0s 4ms/sample - loss: 0.2112 - mean_absolute_error: 0.2112 - val_loss: 0.2542 - val_mean_absolute_error: 0.2542
# Epoch 42/50
# 37/37 [==============================] - 0s 5ms/sample - loss: 0.2681 - mean_absolute_error: 0.2681 - val_loss: 0.2433 - val_mean_absolute_error: 0.2433
# Epoch 43/50
# 37/37 [==============================] - 0s 4ms/sample - loss: 0.2717 - mean_absolute_error: 0.2717 - val_loss: 0.2338 - val_mean_absolute_error: 0.2338
# Epoch 44/50
# 37/37 [==============================] - 0s 4ms/sample - loss: 0.2607 - mean_absolute_error: 0.2607 - val_loss: 0.2243 - val_mean_absolute_error: 0.2243
# Epoch 45/50
# 37/37 [==============================] - 0s 5ms/sample - loss: 0.2725 - mean_absolute_error: 0.2725 - val_loss: 0.2175 - val_mean_absolute_error: 0.2175
# Epoch 46/50
# 37/37 [==============================] - 0s 4ms/sample - loss: 0.2564 - mean_absolute_error: 0.2564 - val_loss: 0.2145 - val_mean_absolute_error: 0.2145
# Epoch 47/50
# 37/37 [==============================] - 0s 4ms/sample - loss: 0.2732 - mean_absolute_error: 0.2732 - val_loss: 0.2172 - val_mean_absolute_error: 0.2172
# Epoch 48/50
# 37/37 [==============================] - 0s 4ms/sample - loss: 0.2483 - mean_absolute_error: 0.2483 - val_loss: 0.2384 - val_mean_absolute_error: 0.2384
# Epoch 49/50
# 37/37 [==============================] - 0s 4ms/sample - loss: 0.2532 - mean_absolute_error: 0.2532 - val_loss: 0.2807 - val_mean_absolute_error: 0.2807
# Epoch 50/50
# 37/37 [==============================] - 0s 4ms/sample - loss: 0.2667 - mean_absolute_error: 0.2667 - val_loss: 0.3329 - val_mean_absolute_error: 0.3329

# %%
result = model.predict(x_test)
result
# Out:
# array([[-0.23124474],
#        [ 0.02377468],
#        [-0.09108256],
#        [-0.00299612],
#        [ 0.18128891],
#        [-0.26701593],
#        [ 0.66691774],
#        [ 0.38794914],
#        [ 0.6715868 ],
#        [ 0.15612999]], dtype=float32)

# %%
res_df = scy.inverse_transform(result)

# %%
y_test_actual=scy.inverse_transform(y_test)

# %%
res_df
# Out:
# array([[294.0489 ],
#        [391.59378],
#        [347.66092],
#        [381.35397],
#        [451.84302],
#        [280.3664 ],
#        [637.59607],
#        [530.89056],
#        [639.38196],
#        [442.2197 ]], dtype=float32)

# %%
y_test_actual
# Out:
# array([[285.],
#        [105.],
#        [315.],
#        [ 45.],
#        [345.],
#        [150.],
#        [540.],
#        [435.],
#        [705.],
#        [330.]])
